# %% [markdown]
# # Visualisations
#
# Une version un clean de la sandbox avec que des visualisations qui fonctionnent.

# %% [markdown]
# ## Liste des variables
#
# Liste des variables démographiques disponibles par circonscription électorale.

# %%
from preprocess import *

df = get_demographics_data()
print(*enumerate(df.columns), sep='\n')

# %% [markdown]
# Liste des variables pour le dataset d'immigration par quartier (pas par circonscription !)

# %%
from preprocess import *

df = get_immigration_data()
print(*enumerate(df.columns), sep='\n')
# Out:
# (0, 'Arrondissement')
# (1, 'Population totale')
# (2, 'Non Immigrante')
# (3, 'Immigrante')
# (4, 'Immigrante Avant 2010')
# (5, 'Immigrante 2011 à 2015')
# (6, 'Immigrante 2016 à 2021')
# (7, 'Résidente Non Permanente')
# (8, 'Population totale - Hommes')
# (9, 'Non Immigrante - Hommes')
# (10, 'Immigrante - Hommes')
# (11, 'Immigrante Avant 2010 - Hommes')
# (12, 'Immigrante 2011 à 2015 - Hommes')
# (13, 'Immigrante 2016 à 2021 - Hommes')
# (14, 'Résidente Non Permanente - Hommes')
# (15, 'Population totale - Femmes')
# (16, 'Non Immigrante - Femmes')
# (17, 'Immigrante - Femmes')
# (18, 'Immigrante Avant 2010 - Femmes')
# (19, 'Immigrante 2011 à 2015 - Femmes')
# (20, 'Immigrante 2016 à 2021 - Femmes')
# (21, 'Résidente Non Permanente - Femmes')
# (22, 'Population totale.1')
# (23, 'Immigrante Economique')
# (24, 'Demandeure Principale')
# (25, 'Demandeure Secondaire')
# (26, 'Immigrante parrainée par la famille')
# (27, 'Réfugiée')
# (28, 'Autre immigrante')
# (29, 'Population totale - Hommes.1')
# (30, 'Immigrante Economique - Hommes')
# (31, 'Demandeure Principale - Hommes')
# (32, 'Demandeure Secondaire - Hommes')
# (33, 'Immigrante parrainée par la famille - Hommes')
# (34, 'Réfugiée - Hommes')
# (35, 'Autre immigrante - Hommes')
# (36, 'Population totale - Femmes.1')
# (37, 'Immigrante Economique - Femmes')
# (38, 'Demandeure Principale - Femmes')
# (39, 'Demandeure Secondaire - Femmes')
# (40, 'Immigrante parrainée par la famille - Femmes')
# (41, 'Réfugiée - Femmes')
# (42, 'Autre immigrante - Femmes')
# (43, 'Population immigrante')
# (44, '0 à 17 ans')
# (45, '0 à 5 ans')
# (46, '6 à 11 ans')
# (47, '12 à 17 ans')
# (48, '18 à 64 ans')
# (49, '18 à 24 ans')
# (50, '25 à 44 ans')
# (51, '45 à 64 ans')
# (52, '65 ans et plus')
# (53, '65 à 84 ans')
# (54, '85 ans et plus')
# (55, 'Population immigrante - Hommes')
# (56, '0 à 17 ans - Hommes')
# (57, '0 à 5 ans - Hommes')
# (58, '6 à 11 ans - Hommes')
# (59, '12 à 17 ans - Hommes')
# (60, '18 à 64 ans - Hommes')
# (61, '18 à 24 ans - Hommes')
# (62, '25 à 44 ans - Hommes')
# (63, '45 à 64 ans - Hommes')
# (64, '65 ans et plus - Hommes')
# (65, '65 à 84 ans - Hommes')
# (66, '85 ans et plus - Hommes')
# (67, 'Population immigrante - Femmes')
# (68, '0 à 17 ans - Femmes')
# (69, '0 à 5 ans - Femmes')
# (70, '6 à 11 ans - Femmes')
# (71, '12 à 17 ans - Femmes')
# (72, '18 à 64 ans - Femmes')
# (73, '18 à 24 ans - Femmes')
# (74, '25 à 44 ans - Femmes')
# (75, '45 à 64 ans - Femmes')
# (76, '65 ans et plus - Femmes')
# (77, '65 à 84 ans - Femmes')
# (78, '85 ans et plus - Femmes')
# (79, 'Non permamente, Population résidente non permanente')
# (80, 'Non permamente, 0 à 17 ans')
# (81, 'Non permamente, 0 à 5 ans')
# (82, 'Non permamente, 6 à 11 ans')
# (83, 'Non permamente, 12 à 17 ans')
# (84, 'Non permamente, 18 à 64 ans')
# (85, 'Non permamente, 18 à 24 ans')
# (86, 'Non permamente, 25 à 44 ans')
# (87, 'Non permamente, 45 à 64 ans')
# (88, 'Non permamente, 65 ans et plus')
# (89, 'Non permamente, 65 à 84 ans')
# (90, 'Non permamente, 85 ans et plus')
# (91, 'Non permamente, Population résidente non permanente - Hommes')
# (92, 'Non permamente, 0 à 17 ans - Hommes')
# (93, 'Non permamente, 0 à 5 ans - Hommes')
# (94, 'Non permamente, 6 à 11 ans - Hommes')
# (95, 'Non permamente, 12 à 17 ans - Hommes')
# (96, 'Non permamente, 18 à 64 ans - Hommes')
# (97, 'Non permamente, 18 à 24 ans - Hommes')
# (98, 'Non permamente, 25 à 44 ans - Hommes')
# (99, 'Non permamente, 45 à 64 ans - Hommes')
# (100, 'Non permamente, 65 ans et plus - Hommes')
# (101, 'Non permamente, 65 à 84 ans - Hommes')
# (102, 'Non permamente, 85 ans et plus - Hommes')
# (103, 'Non permamente, Population résidente non permanente - Femmes')
# (104, 'Non permamente, 0 à 17 ans - Femmes')
# (105, 'Non permamente, 0 à 5 ans - Femmes')
# (106, 'Non permamente, 6 à 11 ans - Femmes')
# (107, 'Non permamente, 12 à 17 ans - Femmes')
# (108, 'Non permamente, 18 à 64 ans - Femmes')
# (109, 'Non permamente, 18 à 24 ans - Femmes')
# (110, 'Non permamente, 25 à 44 ans - Femmes')
# (111, 'Non permamente, 45 à 64 ans - Femmes')
# (112, 'Non permamente, 65 ans et plus - Femmes')
# (113, 'Non permamente, 65 à 84 ans - Femmes')
# (114, 'Non permamente, 85 ans et plus - Femmes')
# (115, "Âge à l'immigration, Population immigrante")
# (116, "Âge à l'immigration, Moins de 5 ans")
# (117, "Âge à l'immigration, 5 à 14 ans")
# (118, "Âge à l'immigration, 15 à 24 ans")
# (119, "Âge à l'immigration, 25 à 44 ans")
# (120, "Âge à l'immigration, 45 ans et plus")
# (121, "Âge à l'immigration, Population immigrante - Hommes")
# (122, "Âge à l'immigration, Moins de 5 ans - Hommes")
# (123, "Âge à l'immigration, 5 à 14 ans - Hommes")
# (124, "Âge à l'immigration, 15 à 24 ans - Hommes")
# (125, "Âge à l'immigration, 25 à 44 ans - Hommes")
# (126, "Âge à l'immigration, 45 ans et plus - Hommes")
# (127, "Âge à l'immigration, Population immigrante - Femmes")
# (128, "Âge à l'immigration, Moins de 5 ans - Femmes")
# (129, "Âge à l'immigration, 5 à 14 ans - Femmes")
# (130, "Âge à l'immigration, 15 à 24 ans - Femmes")
# (131, "Âge à l'immigration, 25 à 44 ans - Femmes")
# (132, "Âge à l'immigration, 45 ans et plus - Femmes")
# (133, 'Population immigrante.1')
# (134, 'Continent Amériques')
# (135, 'Bresil')
# (136, 'Colombie')
# (137, 'El Salvador')
# (138, 'Guyana')
# (139, 'Haiti')
# (140, 'Jamaique')
# (141, 'Mexique')
# (142, 'Pérou')
# (143, 'Trinité-et-Tobago')
# (144, 'États-Unis')
# (145, 'Autres lieux de naissance en Amériques')
# (146, 'Continent Europe')
# (147, 'Bosnie-Herzégovine')
# (148, 'Croatie')
# (149, 'France')
# (150, 'Allemagne')
# (151, 'Grèce')
# (152, 'Hongrie')
# (153, 'Italie')
# (154, 'Pays Bas')
# (155, 'Pologne')
# (156, 'Portugal')
# (157, 'Roumanie')
# (158, 'Russie')
# (159, 'Serbie')
# (160, 'Ukraine')
# (161, 'Royaume-Uni')
# (162, 'Autres lieux de naissance en Europe')
# (163, 'Continent Afrique')
# (164, 'Algérie')
# (165, 'Congo RDC')
# (166, 'Égypte')
# (167, 'Érythrée')
# (168, 'Éthiopie')
# (169, 'Maroc')
# (170, 'Nigéria')
# (171, 'Somalie')
# (172, 'Afrique du Sud')
# (173, 'Autres lieux de naissance en Afrique')
# (174, 'Continent Asie')
# (175, 'Afghanistan')
# (176, 'Iran')
# (177, 'Iraq')
# (178, 'Liban')
# (179, 'Syrie')
# (180, 'Turquie')
# (181, 'Chine')
# (182, 'Hong Kong')
# (183, 'Corée Sud')
# (184, 'Taiwan')
# (185, 'Philippines')
# (186, 'Viet Nam')
# (187, 'Bangladesh')
# (188, 'Inde')
# (189, 'Pakistan')
# (190, 'Sri Lanka')
# (191, 'Autres lieux de naissance en Asie')
# (192, 'Continent Oceanie et autres lieux de naissance')
# (193, 'Population immigrante - Hommes.1')
# (194, 'Continent Amériques - Hommes')
# (195, 'Bresil - Hommes')
# (196, 'Colombie - Hommes')
# (197, 'El Salvador - Hommes')
# (198, 'Guyana - Hommes')
# (199, 'Haiti - Hommes')
# (200, 'Jamaique - Hommes')
# (201, 'Mexique - Hommes')
# (202, 'Pérou - Hommes')
# (203, 'Trinité-et-Tobago - Hommes')
# (204, 'États-Unis - Hommes')
# (205, 'Autres lieux de naissance en Amériques - Hommes')
# (206, 'Continent Europe - Hommes')
# (207, 'Bosnie-Herzégovine - Hommes')
# (208, 'Croatie - Hommes')
# (209, 'France - Hommes')
# (210, 'Allemagne - Hommes')
# (211, 'Grèce - Hommes')
# (212, 'Hongrie - Hommes')
# (213, 'Italie - Hommes')
# (214, 'Pays Bas - Hommes')
# (215, 'Pologne - Hommes')
# (216, 'Portugal - Hommes')
# (217, 'Roumanie - Hommes')
# (218, 'Russie - Hommes')
# (219, 'Serbie - Hommes')
# (220, 'Ukraine - Hommes')
# (221, 'Royaume-Uni - Hommes')
# (222, 'Autres lieux de naissance en Europe - Hommes')
# (223, 'Continent Afrique - Hommes')
# (224, 'Algérie - Hommes')
# (225, 'Congo RDC - Hommes')
# (226, 'Égypte - Hommes')
# (227, 'Érythrée - Hommes')
# (228, 'Éthiopie - Hommes')
# (229, 'Maroc - Hommes')
# (230, 'Nigéria - Hommes')
# (231, 'Somalie - Hommes')
# (232, 'Afrique du Sud - Hommes')
# (233, 'Autres lieux de naissance en Afrique - Hommes')
# (234, 'Continent Asie - Hommes')
# (235, 'Afghanistan - Hommes')
# (236, 'Iran - Hommes')
# (237, 'Iraq - Hommes')
# (238, 'Liban - Hommes')
# (239, 'Syrie - Hommes')
# (240, 'Turquie - Hommes')
# (241, 'Chine - Hommes')
# (242, 'Hong Kong - Hommes')
# (243, 'Corée Sud - Hommes')
# (244, 'Taiwan - Hommes')
# (245, 'Philippines - Hommes')
# (246, 'Viet Nam - Hommes')
# (247, 'Bangladesh - Hommes')
# (248, 'Inde - Hommes')
# (249, 'Pakistan - Hommes')
# (250, 'Sri Lanka - Hommes')
# (251, 'Autres lieux de naissance en Asie - Hommes')
# (252, 'Continent Oceanie et autres lieux de naissance - Hommes')
# (253, 'Population immigrante - Femmes.1')
# (254, 'Continent Amériques - Femmes')
# (255, 'Bresil - Femmes')
# (256, 'Colombie - Femmes')
# (257, 'El Salvador - Femmes')
# (258, 'Guyana - Femmes')
# (259, 'Haiti - Femmes')
# (260, 'Jamaique - Femmes')
# (261, 'Mexique - Femmes')
# (262, 'Pérou - Femmes')
# (263, 'Trinité-et-Tobago - Femmes')
# (264, 'États-Unis - Femmes')
# (265, 'Autres lieux de naissance en Amériques - Femmes')
# (266, 'Continent Europe - Femmes')
# (267, 'Bosnie-Herzégovine - Femmes')
# (268, 'Croatie - Femmes')
# (269, 'France - Femmes')
# (270, 'Allemagne - Femmes')
# (271, 'Grèce - Femmes')
# (272, 'Hongrie - Femmes')
# (273, 'Italie - Femmes')
# (274, 'Pays Bas - Femmes')
# (275, 'Pologne - Femmes')
# (276, 'Portugal - Femmes')
# (277, 'Roumanie - Femmes')
# (278, 'Russie - Femmes')
# (279, 'Serbie - Femmes')
# (280, 'Ukraine - Femmes')
# (281, 'Royaume-Uni - Femmes')
# (282, 'Autres lieux de naissance en Europe - Femmes')
# (283, 'Continent Afrique - Femmes')
# (284, 'Algérie - Femmes')
# (285, 'Congo RDC - Femmes')
# (286, 'Égypte - Femmes')
# (287, 'Érythrée - Femmes')
# (288, 'Éthiopie - Femmes')
# (289, 'Maroc - Femmes')
# (290, 'Nigéria - Femmes')
# (291, 'Somalie - Femmes')
# (292, 'Afrique du Sud - Femmes')
# (293, 'Autres lieux de naissance en Afrique - Femmes')
# (294, 'Continent Asie - Femmes')
# (295, 'Afghanistan - Femmes')
# (296, 'Iran - Femmes')
# (297, 'Iraq - Femmes')
# (298, 'Liban - Femmes')
# (299, 'Syrie - Femmes')
# (300, 'Turquie - Femmes')
# (301, 'Chine - Femmes')
# (302, 'Hong Kong - Femmes')
# (303, 'Corée Sud - Femmes')
# (304, 'Taiwan - Femmes')
# (305, 'Philippines - Femmes')
# (306, 'Viet Nam - Femmes')
# (307, 'Bangladesh - Femmes')
# (308, 'Inde - Femmes')
# (309, 'Pakistan - Femmes')
# (310, 'Sri Lanka - Femmes')
# (311, 'Autres lieux de naissance en Asie - Femmes')
# (312, 'Continent Oceanie et autres lieux de naissance - Femmes')
# (313, 'Imigration récente (entre 2016 et 2021), Population immigrante')
# (314, 'Imigration récente (entre 2016 et 2021), Continent Amériques')
# (315, 'Imigration récente (entre 2016 et 2021), Brésil')
# (316, 'Imigration récente (entre 2016 et 2021), Colombie')
# (317, 'Imigration récente (entre 2016 et 2021), HaÃ¯ti')
# (318, 'Imigration récente (entre 2016 et 2021), JamaÃ¯que')
# (319, 'Imigration récente (entre 2016 et 2021), Mexique')
# (320, 'Imigration récente (entre 2016 et 2021), États-Unis')
# (321, 'Imigration récente (entre 2016 et 2021), Venezuela')
# (322, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Amériques')
# (323, 'Imigration récente (entre 2016 et 2021), Continent Europe')
# (324, 'Imigration récente (entre 2016 et 2021), France')
# (325, 'Imigration récente (entre 2016 et 2021), Allemagne')
# (326, 'Imigration récente (entre 2016 et 2021), Irlande')
# (327, 'Imigration récente (entre 2016 et 2021), Italie')
# (328, 'Imigration récente (entre 2016 et 2021), Russie')
# (329, 'Imigration récente (entre 2016 et 2021), Ukraine')
# (330, 'Imigration récente (entre 2016 et 2021), Royaume-Uni')
# (331, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Europe')
# (332, 'Imigration récente (entre 2016 et 2021), Continent Afrique')
# (333, 'Imigration récente (entre 2016 et 2021), Algérie')
# (334, 'Imigration récente (entre 2016 et 2021), Burundi')
# (335, 'Imigration récente (entre 2016 et 2021), Cameroun')
# (336, 'Imigration récente (entre 2016 et 2021), Congo RDC')
# (337, "Imigration récente (entre 2016 et 2021), Côte d'Ivoire")
# (338, 'Imigration récente (entre 2016 et 2021), Égypte')
# (339, 'Imigration récente (entre 2016 et 2021), Érythrée')
# (340, 'Imigration récente (entre 2016 et 2021), Éthiopie')
# (341, 'Imigration récente (entre 2016 et 2021), Maroc')
# (342, 'Imigration récente (entre 2016 et 2021), Nigéria')
# (343, 'Imigration récente (entre 2016 et 2021), Somalie')
# (344, 'Imigration récente (entre 2016 et 2021), Afrique du Sud')
# (345, 'Imigration récente (entre 2016 et 2021), Soudan')
# (346, 'Imigration récente (entre 2016 et 2021), Tunisie')
# (347, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Afrique')
# (348, 'Imigration récente (entre 2016 et 2021), Continent Asie')
# (349, 'Imigration récente (entre 2016 et 2021), Afghanistan')
# (350, 'Imigration récente (entre 2016 et 2021), Bangladesh')
# (351, 'Imigration récente (entre 2016 et 2021), Chine')
# (352, 'Imigration récente (entre 2016 et 2021), Hong Kong')
# (353, 'Imigration récente (entre 2016 et 2021), Inde')
# (354, 'Imigration récente (entre 2016 et 2021), Iran')
# (355, 'Imigration récente (entre 2016 et 2021), Iraq')
# (356, 'Imigration récente (entre 2016 et 2021), IsraÃ«l')
# (357, 'Imigration récente (entre 2016 et 2021), Japon')
# (358, 'Imigration récente (entre 2016 et 2021), Jordanie')
# (359, 'Imigration récente (entre 2016 et 2021), Corée du Sud')
# (360, 'Imigration récente (entre 2016 et 2021), Liban')
# (361, 'Imigration récente (entre 2016 et 2021), Nepal')
# (362, 'Imigration récente (entre 2016 et 2021), Pakistan')
# (363, 'Imigration récente (entre 2016 et 2021), Philippines')
# (364, 'Imigration récente (entre 2016 et 2021), Arabie Saoudite')
# (365, 'Imigration récente (entre 2016 et 2021), Sri Lanka')
# (366, 'Imigration récente (entre 2016 et 2021), Syrie')
# (367, 'Imigration récente (entre 2016 et 2021), Turquie')
# (368, 'Imigration récente (entre 2016 et 2021), Émirats arabes unis')
# (369, 'Imigration récente (entre 2016 et 2021), Viet Nam')
# (370, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Asie')
# (371, 'Imigration récente (entre 2016 et 2021), Continent Oceanie')
# (372, 'Imigration récente (entre 2016 et 2021), Australie')
# (373, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance')
# (374, 'Imigration récente (entre 2016 et 2021), Population immigrante - Hommes')
# (375, 'Imigration récente (entre 2016 et 2021), Continent Amériques - Hommes')
# (376, 'Imigration récente (entre 2016 et 2021), Brésil - Hommes')
# (377, 'Imigration récente (entre 2016 et 2021), Colombie - Hommes')
# (378, 'Imigration récente (entre 2016 et 2021), HaÃ¯ti - Hommes')
# (379, 'Imigration récente (entre 2016 et 2021), JamaÃ¯que - Hommes')
# (380, 'Imigration récente (entre 2016 et 2021), Mexique - Hommes')
# (381, 'Imigration récente (entre 2016 et 2021), États-Unis - Hommes')
# (382, 'Imigration récente (entre 2016 et 2021), Venezuela - Hommes')
# (383, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Amériques - Hommes')
# (384, 'Imigration récente (entre 2016 et 2021), Continent Europe - Hommes')
# (385, 'Imigration récente (entre 2016 et 2021), France - Hommes')
# (386, 'Imigration récente (entre 2016 et 2021), Allemagne - Hommes')
# (387, 'Imigration récente (entre 2016 et 2021), Irlande - Hommes')
# (388, 'Imigration récente (entre 2016 et 2021), Italie - Hommes')
# (389, 'Imigration récente (entre 2016 et 2021), Russie - Hommes')
# (390, 'Imigration récente (entre 2016 et 2021), Ukraine - Hommes')
# (391, 'Imigration récente (entre 2016 et 2021), Royaume-Uni - Hommes')
# (392, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Europe - Hommes')
# (393, 'Imigration récente (entre 2016 et 2021), Continent Afrique - Hommes')
# (394, 'Imigration récente (entre 2016 et 2021), Algérie - Hommes')
# (395, 'Imigration récente (entre 2016 et 2021), Burundi - Hommes')
# (396, 'Imigration récente (entre 2016 et 2021), Cameroun - Hommes')
# (397, 'Imigration récente (entre 2016 et 2021), Congo RDC - Hommes')
# (398, "Imigration récente (entre 2016 et 2021), Côte d'Ivoire - Hommes")
# (399, 'Imigration récente (entre 2016 et 2021), Égypte - Hommes')
# (400, 'Imigration récente (entre 2016 et 2021), Érythrée - Hommes')
# (401, 'Imigration récente (entre 2016 et 2021), Éthiopie - Hommes')
# (402, 'Imigration récente (entre 2016 et 2021), Maroc - Hommes')
# (403, 'Imigration récente (entre 2016 et 2021), Nigéria - Hommes')
# (404, 'Imigration récente (entre 2016 et 2021), Somalie - Hommes')
# (405, 'Imigration récente (entre 2016 et 2021), Afrique du Sud - Hommes')
# (406, 'Imigration récente (entre 2016 et 2021), Soudan - Hommes')
# (407, 'Imigration récente (entre 2016 et 2021), Tunisie - Hommes')
# (408, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Afrique - Hommes')
# (409, 'Imigration récente (entre 2016 et 2021), Continent Asie - Hommes')
# (410, 'Imigration récente (entre 2016 et 2021), Afghanistan - Hommes')
# (411, 'Imigration récente (entre 2016 et 2021), Bangladesh - Hommes')
# (412, 'Imigration récente (entre 2016 et 2021), Chine - Hommes')
# (413, 'Imigration récente (entre 2016 et 2021), Hong Kong - Hommes')
# (414, 'Imigration récente (entre 2016 et 2021), Inde - Hommes')
# (415, 'Imigration récente (entre 2016 et 2021), Iran - Hommes')
# (416, 'Imigration récente (entre 2016 et 2021), Iraq - Hommes')
# (417, 'Imigration récente (entre 2016 et 2021), IsraÃ«l - Hommes')
# (418, 'Imigration récente (entre 2016 et 2021), Japon - Hommes')
# (419, 'Imigration récente (entre 2016 et 2021), Jordanie - Hommes')
# (420, 'Imigration récente (entre 2016 et 2021), Corée du Sud - Hommes')
# (421, 'Imigration récente (entre 2016 et 2021), Liban - Hommes')
# (422, 'Imigration récente (entre 2016 et 2021), Nepal - Hommes')
# (423, 'Imigration récente (entre 2016 et 2021), Pakistan - Hommes')
# (424, 'Imigration récente (entre 2016 et 2021), Philippines - Hommes')
# (425, 'Imigration récente (entre 2016 et 2021), Arabie Saoudite - Hommes')
# (426, 'Imigration récente (entre 2016 et 2021), Sri Lanka - Hommes')
# (427, 'Imigration récente (entre 2016 et 2021), Syrie - Hommes')
# (428, 'Imigration récente (entre 2016 et 2021), Turquie - Hommes')
# (429, 'Imigration récente (entre 2016 et 2021), Émirats arabes unis - Hommes')
# (430, 'Imigration récente (entre 2016 et 2021), Viet Nam - Hommes')
# (431, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Asie - Hommes')
# (432, 'Imigration récente (entre 2016 et 2021), Continent Oceanie - Hommes')
# (433, 'Imigration récente (entre 2016 et 2021), Australie - Hommes')
# (434, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance - Hommes')
# (435, 'Imigration récente (entre 2016 et 2021), Population immigrante - Femmes')
# (436, 'Imigration récente (entre 2016 et 2021), Continent Amériques - Femmes')
# (437, 'Imigration récente (entre 2016 et 2021), Brésil - Femmes')
# (438, 'Imigration récente (entre 2016 et 2021), Colombie - Femmes')
# (439, 'Imigration récente (entre 2016 et 2021), HaÃ¯ti - Femmes')
# (440, 'Imigration récente (entre 2016 et 2021), JamaÃ¯que - Femmes')
# (441, 'Imigration récente (entre 2016 et 2021), Mexique - Femmes')
# (442, 'Imigration récente (entre 2016 et 2021), États-Unis - Femmes')
# (443, 'Imigration récente (entre 2016 et 2021), Venezuela - Femmes')
# (444, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Amériques - Femmes')
# (445, 'Imigration récente (entre 2016 et 2021), Continent Europe - Femmes')
# (446, 'Imigration récente (entre 2016 et 2021), France - Femmes')
# (447, 'Imigration récente (entre 2016 et 2021), Allemagne - Femmes')
# (448, 'Imigration récente (entre 2016 et 2021), Irlande - Femmes')
# (449, 'Imigration récente (entre 2016 et 2021), Italie - Femmes')
# (450, 'Imigration récente (entre 2016 et 2021), Russie - Femmes')
# (451, 'Imigration récente (entre 2016 et 2021), Ukraine - Femmes')
# (452, 'Imigration récente (entre 2016 et 2021), Royaume-Uni - Femmes')
# (453, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Europe - Femmes')
# (454, 'Imigration récente (entre 2016 et 2021), Continent Afrique - Femmes')
# (455, 'Imigration récente (entre 2016 et 2021), Algérie - Femmes')
# (456, 'Imigration récente (entre 2016 et 2021), Burundi - Femmes')
# (457, 'Imigration récente (entre 2016 et 2021), Cameroun - Femmes')
# (458, 'Imigration récente (entre 2016 et 2021), Congo RDC - Femmes')
# (459, "Imigration récente (entre 2016 et 2021), Côte d'Ivoire - Femmes")
# (460, 'Imigration récente (entre 2016 et 2021), Égypte - Femmes')
# (461, 'Imigration récente (entre 2016 et 2021), Érythrée - Femmes')
# (462, 'Imigration récente (entre 2016 et 2021), Éthiopie - Femmes')
# (463, 'Imigration récente (entre 2016 et 2021), Maroc - Femmes')
# (464, 'Imigration récente (entre 2016 et 2021), Nigéria - Femmes')
# (465, 'Imigration récente (entre 2016 et 2021), Somalie - Femmes')
# (466, 'Imigration récente (entre 2016 et 2021), Afrique du Sud - Femmes')
# (467, 'Imigration récente (entre 2016 et 2021), Soudan - Femmes')
# (468, 'Imigration récente (entre 2016 et 2021), Tunisie - Femmes')
# (469, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Afrique - Femmes')
# (470, 'Imigration récente (entre 2016 et 2021), Continent Asie - Femmes')
# (471, 'Imigration récente (entre 2016 et 2021), Afghanistan - Femmes')
# (472, 'Imigration récente (entre 2016 et 2021), Bangladesh - Femmes')
# (473, 'Imigration récente (entre 2016 et 2021), Chine - Femmes')
# (474, 'Imigration récente (entre 2016 et 2021), Hong Kong - Femmes')
# (475, 'Imigration récente (entre 2016 et 2021), Inde - Femmes')
# (476, 'Imigration récente (entre 2016 et 2021), Iran - Femmes')
# (477, 'Imigration récente (entre 2016 et 2021), Iraq - Femmes')
# (478, 'Imigration récente (entre 2016 et 2021), IsraÃ«l - Femmes')
# (479, 'Imigration récente (entre 2016 et 2021), Japon - Femmes')
# (480, 'Imigration récente (entre 2016 et 2021), Jordanie - Femmes')
# (481, 'Imigration récente (entre 2016 et 2021), Corée du Sud - Femmes')
# (482, 'Imigration récente (entre 2016 et 2021), Liban - Femmes')
# (483, 'Imigration récente (entre 2016 et 2021), Nepal - Femmes')
# (484, 'Imigration récente (entre 2016 et 2021), Pakistan - Femmes')
# (485, 'Imigration récente (entre 2016 et 2021), Philippines - Femmes')
# (486, 'Imigration récente (entre 2016 et 2021), Arabie Saoudite - Femmes')
# (487, 'Imigration récente (entre 2016 et 2021), Sri Lanka - Femmes')
# (488, 'Imigration récente (entre 2016 et 2021), Syrie - Femmes')
# (489, 'Imigration récente (entre 2016 et 2021), Turquie - Femmes')
# (490, 'Imigration récente (entre 2016 et 2021), Émirats arabes unis - Femmes')
# (491, 'Imigration récente (entre 2016 et 2021), Viet Nam - Femmes')
# (492, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance en Asie - Femmes')
# (493, 'Imigration récente (entre 2016 et 2021), Continent Oceanie - Femmes')
# (494, 'Imigration récente (entre 2016 et 2021), Australie - Femmes')
# (495, 'Imigration récente (entre 2016 et 2021), Autres lieux de naissance - Femmes')
# (496, 'Population immigrante.2')
# (497, "Demande d'asile avant l'admission")
# (498, "Permis de travail seulement avant l'admission")
# (499, "Permis d'études seulement avant l'admission")
# (500, "Permis de travail et d'études avant l'admission")
# (501, "Autres permis avant l'admission")
# (502, "Sans expérience avant l'admission")
# (503, 'Population immigrante - Hommes.2')
# (504, "Demande d'asile avant l'admission - Hommes")
# (505, "Permis de travail seulement avant l'admission - Hommes")
# (506, "Permis d'études seulement avant l'admission - Hommes")
# (507, "Permis de travail et d'études avant l'admission - Hommes")
# (508, "Autres permis avant l'admission - Hommes")
# (509, "Sans expérience avant l'admission - Hommes")
# (510, 'Population immigrante - Femmes.2')
# (511, "Demande d'asile avant l'admission - Femmes")
# (512, "Permis de travail seulement avant l'admission - Femmes")
# (513, "Permis d'études seulement avant l'admission - Femmes")
# (514, "Permis de travail et d'études avant l'admission - Femmes")
# (515, "Autres permis avant l'admission - Femmes")
# (516, "Sans expérience avant l'admission - Femmes")
# (517, 'Population totale.2')
# (518, 'Première génération')
# (519, 'Deuxième génération')
# (520, 'Troisième génération ou plus')
# (521, 'Population totale - Hommes.2')
# (522, 'Première génération - Hommes')
# (523, 'Deuxième génération - Hommes')
# (524, 'Troisième génération ou plus - Hommes')
# (525, 'Population totale - Femmes.2')
# (526, 'Première génération - Femmes')
# (527, 'Deuxième génération - Femmes')
# (528, 'Troisième génération ou plus - Femmes')
# (529, 'Population immigrante (PI)')
# (530, "PI s'identifiant comme personne racisée")
# (531, "PI ne s'identifiant pas comme personne racisée")
# (532, 'Population résidente permanente (PRNP)')
# (533, "PRNP s'identifiant comme personne racisée")
# (534, "PRNP ne s'identifiant pas comme personne racisée")
# (535, 'Population immigrante (PI) - Hommes')
# (536, "PI s'identifiant comme personne racisée - Hommes")
# (537, "PI ne s'identifiant pas comme personne racisée - Hommes")
# (538, 'Population résidente permanente (PRNP) - Hommes')
# (539, "PRNP s'identifiant comme personne racisée - Hommes")
# (540, "PRNP ne s'identifiant pas comme personne racisée - Hommes")
# (541, 'Population immigrante (PI) - Femmes')
# (542, "PI s'identifiant comme personne racisée - Femmes")
# (543, "PI ne s'identifiant pas comme personne racisée - Femmes")
# (544, 'Population résidente permanente (PRNP) - Femmes')
# (545, "PRNP s'identifiant comme personne racisée - Femmes")
# (546, "PRNP ne s'identifiant pas comme personne racisée - Femmes")
# (547, 'Répartition selon la connaissance des langues officielles')
# (548, 'Parlant anglais seulement')
# (549, 'Parlant français seulement')
# (550, 'Parlant français et anglais')
# (551, 'Ne parlant ni français ni anglais')
# (552, 'Répartition selon la langue parlée à la maison')
# (553, 'Parlant anglais à la maison')
# (554, 'Parlant français à la maison')
# (555, 'Parlant une langue non officielle à la maison')
# (556, 'Parlant français et anglais à la maison')
# (557, 'Parlant anglais et une langue non officielle à la maison')
# (558, 'Parlant français et une langue non officielle à la maison')
# (559, 'Parlant français, anglais et une langue non officielle à la maison')
# (560, 'Parlant plusieurs langues non officielles à la maison')
# (561, 'Répartition selon la connaissance des langues officielles - Hommes')
# (562, 'Parlant anglais seulement - Hommes')
# (563, 'Parlant français seulement - Hommes')
# (564, 'Parlant français et anglais - Hommes')
# (565, 'Ne parlant ni français ni anglais - Hommes')
# (566, 'Répartition selon la langue parlée à la maison - Hommes')
# (567, 'Parlant anglais à la maison - Hommes')
# (568, 'Parlant français à la maison - Hommes')
# (569, 'Parlant une langue non officielle à la maison - Hommes')
# (570, 'Parlant français et anglais à la maison - Hommes')
# (571, 'Parlant anglais et une langue non officielle à la maison - Hommes')
# (572, 'Parlant français et une langue non officielle à la maison - Hommes')
# (573, 'Parlant français, anglais et une langue non officielle à la maison - Hommes')
# (574, 'Parlant plusieurs langues non officielles à la maison - Hommes')
# (575, 'Répartition selon la connaissance des langues officielles - Femmes')
# (576, 'Parlant anglais seulement - Femmes')
# (577, 'Parlant français seulement - Femmes')
# (578, 'Parlant français et anglais - Femmes')
# (579, 'Ne parlant ni français ni anglais - Femmes')
# (580, 'Répartition selon la langue parlée à la maison - Femmes')
# (581, 'Parlant anglais à la maison - Femmes')
# (582, 'Parlant français à la maison - Femmes')
# (583, 'Parlant une langue non officielle à la maison - Femmes')
# (584, 'Parlant français et anglais à la maison - Femmes')
# (585, 'Parlant anglais et une langue non officielle à la maison - Femmes')
# (586, 'Parlant français et une langue non officielle à la maison - Femmes')
# (587, 'Parlant français, anglais et une langue non officielle à la maison - Femmes')
# (588, 'Parlant plusieurs langues non officielles à la maison - Femmes')
# (589, 'Non permanente, Répartition selon la connaissance des langues officielles')
# (590, 'Non permanente, Parlant anglais seulement')
# (591, 'Non permanente, Parlant français seulement')
# (592, 'Non permanente, Parlant français et anglais')
# (593, 'Non permanente, Ne parlant ni français ni anglais')
# (594, 'Non permanente, Répartition selon la langue parlée à la maison')
# (595, 'Non permanente, Parlant anglais à la maison')
# (596, 'Non permanente, Parlant français à la maison')
# (597, 'Non permanente, Parlant une langue non officielle à la maison')
# (598, 'Non permanente, Parlant français et anglais à la maison')
# (599, 'Non permanente, Parlant anglais et une langue non officielle à la maison')
# (600, 'Non permanente, Parlant français et une langue non officielle à la maison')
# (601, 'Non permanente, Parlant français, anglais et une langue non officielle à la maison')
# (602, 'Non permanente, Parlant plusieurs langues non officielles à la maison')
# (603, 'Non permanente, Répartition selon la connaissance des langues officielles - Hommes')
# (604, 'Non permanente, Parlant anglais seulement - Hommes')
# (605, 'Non permanente, Parlant français seulement - Hommes')
# (606, 'Non permanente, Parlant français et anglais - Hommes')
# (607, 'Non permanente, Ne parlant ni français ni anglais - Hommes')
# (608, 'Non permanente, Répartition selon la langue parlée à la maison - Hommes')
# (609, 'Non permanente, Parlant anglais à la maison - Hommes')
# (610, 'Non permanente, Parlant français à la maison - Hommes')
# (611, 'Non permanente, Parlant une langue non officielle à la maison - Hommes')
# (612, 'Non permanente, Parlant français et anglais à la maison - Hommes')
# (613, 'Non permanente, Parlant anglais et une langue non officielle à la maison - Hommes')
# (614, 'Non permanente, Parlant français et une langue non officielle à la maison - Hommes')
# (615, 'Non permanente, Parlant français, anglais et une langue non officielle à la maison - Hommes')
# (616, 'Non permanente, Parlant plusieurs langues non officielles à la maison - Hommes')
# (617, 'Non permanente, Répartition selon la connaissance des langues officielles - Femmes')
# (618, 'Non permanente, Parlant anglais seulement - Femmes')
# (619, 'Non permanente, Parlant français seulement - Femmes')
# (620, 'Non permanente, Parlant français et anglais - Femmes')
# (621, 'Non permanente, Ne parlant ni français ni anglais - Femmes')
# (622, 'Non permanente, Répartition selon la langue parlée à la maison - Femmes')
# (623, 'Non permanente, Parlant anglais à la maison - Femmes')
# (624, 'Non permanente, Parlant français à la maison - Femmes')
# (625, 'Non permanente, Parlant une langue non officielle à la maison - Femmes')
# (626, 'Non permanente, Parlant français et anglais à la maison - Femmes')
# (627, 'Non permanente, Parlant anglais et une langue non officielle à la maison - Femmes')
# (628, 'Non permanente, Parlant français et une langue non officielle à la maison - Femmes')
# (629, 'Non permanente, Parlant français, anglais et une langue non officielle à la maison - Femmes')
# (630, 'Non permanente, Parlant plusieurs langues non officielles à la maison - Femmes')
# (631, 'Population non-immigrante (PNI)')
# (632, 'PNI - Revenu total médian')
# (633, 'PNI - Revenu après impôt médian')
# (634, 'PNI - Revenu du marché médian')
# (635, "PNI - Revenu d'emploi médian")
# (636, 'PNI - Transferts gouvernementaux médians')
# (637, "PNI - Prestations de l'assurance emploi médianes")
# (638, "PNI - COVID-19 prestations d'urgence et de relance économique médianes")
# (639, 'Population immigrante (PI).1')
# (640, 'PI - Revenu total médian')
# (641, 'PI - Revenu après impôt médian')
# (642, 'PI - Revenu du marché médian')
# (643, "PI - Revenu d'emploi médian")
# (644, 'PI - Transferts gouvernementaux médians')
# (645, "PI - Prestations de l'assurance emploi médianes")
# (646, "PI - COVID-19 prestations d'urgence et de relance économique médianes")
# (647, 'Population résidente non permanente (PRNP)')
# (648, 'PRNP - Revenu total médian')
# (649, 'PRNP - Revenu après impôt médian')
# (650, 'PRNP - Revenu du marché médian')
# (651, "PRNP - Revenu d'emploi médian")
# (652, 'PRNP - Transferts gouvernementaux médians')
# (653, "PRNP - Prestations de l'assurance emploi médianes")
# (654, "PRNP - COVID-19 prestations d'urgence et de relance économique médianes")
# (655, 'Population non-immigrante (PNI) - Hommes')
# (656, 'PNI - Revenu total médian - Hommes')
# (657, 'PNI - Revenu après impôt médian - Hommes')
# (658, 'PNI - Revenu du marché médian - Hommes')
# (659, "PNI - Revenu d'emploi médian - Hommes")
# (660, 'PNI - Transferts gouvernementaux médians - Hommes')
# (661, "PNI - Prestations de l'assurance emploi médianes - Hommes")
# (662, "PNI - COVID-19 prestations d'urgence et de relance économique médianes - Hommes")
# (663, 'Population immigrante (PI) - Hommes.1')
# (664, 'PI - Revenu total médian - Hommes')
# (665, 'PI - Revenu après impôt médian - Hommes')
# (666, 'PI - Revenu du marché médian - Hommes')
# (667, "PI - Revenu d'emploi médian - Hommes")
# (668, 'PI - Transferts gouvernementaux médians - Hommes')
# (669, "PI - Prestations de l'assurance emploi médianes - Hommes")
# (670, "PI - COVID-19 prestations d'urgence et de relance économique médianes - Hommes")
# (671, 'Population résidente non permanente (PRNP) - Hommes')
# (672, 'PRNP - Revenu total médian - Hommes')
# (673, 'PRNP - Revenu après impôt médian - Hommes')
# (674, 'PRNP - Revenu du marché médian - Hommes')
# (675, "PRNP - Revenu d'emploi médian - Hommes")
# (676, 'PRNP - Transferts gouvernementaux médians - Hommes')
# (677, "PRNP - Prestations de l'assurance emploi médianes - Hommes")
# (678, "PRNP - COVID-19 prestations d'urgence et de relance économique médianes - Hommes")
# (679, 'Population non-immigrante (PNI) - Femmes')
# (680, 'PNI - Revenu total médian - Femmes')
# (681, 'PNI - Revenu après impôt médian - Femmes')
# (682, 'PNI - Revenu du marché médian - Femmes')
# (683, "PNI - Revenu d'emploi médian - Femmes")
# (684, 'PNI - Transferts gouvernementaux médians - Femmes')
# (685, "PNI - Prestations de l'assurance emploi médianes - Femmes")
# (686, "PNI - COVID-19 prestations d'urgence et de relance économique médianes - Femmes")
# (687, 'Population immigrante (PI) - Femmes.1')
# (688, 'PI - Revenu total médian - Femmes')
# (689, 'PI - Revenu après impôt médian - Femmes')
# (690, 'PI - Revenu du marché médian - Femmes')
# (691, "PI - Revenu d'emploi médian - Femmes")
# (692, 'PI - Transferts gouvernementaux médians - Femmes')
# (693, "PI - Prestations de l'assurance emploi médianes - Femmes")
# (694, "PI - COVID-19 prestations d'urgence et de relance économique médianes - Femmes")
# (695, 'Population résidente non permanente (PRNP) - Femmes')
# (696, 'PRNP - Revenu total médian - Femmes')
# (697, 'PRNP - Revenu après impôt médian - Femmes')
# (698, 'PRNP - Revenu du marché médian - Femmes')
# (699, "PRNP - Revenu d'emploi médian - Femmes")
# (700, 'PRNP - Transferts gouvernementaux médians - Femmes')
# (701, "PRNP - Prestations de l'assurance emploi médianes - Femmes")
# (702, "PRNP - COVID-19 prestations d'urgence et de relance économique médianes - Femmes")
# (703, 'Population totale (PT)')
# (704, 'PT à faible revenu (SFR-ApI)')
# (705, 'Population non immigrante (PNI)')
# (706, 'PNI à faible revenu (SFR-ApI)')
# (707, 'Population immigrante (PI).2')
# (708, 'PI à faible revenu (SFR-ApI)')
# (709, 'PI - Avant 2010')
# (710, 'Avant 2010 à faible revenu (SFR-ApI)')
# (711, 'PI - 2011 à 2015')
# (712, '2011 à 2015 à faible revenu (SFR-ApI)')
# (713, 'PI - 2016 à 2021')
# (714, '2016 à 2021 à faible revenu (SFR-ApI)')
# (715, 'Population résidente non permanente (PRNP).1')
# (716, 'PRNP à faible revenu (SFR-ApI)')
# (717, 'Population totale (PT) - Hommes')
# (718, 'PT à faible revenu (SFR-ApI) - Hommes')
# (719, 'Population non immigrante (PNI) - Hommes')
# (720, 'PNI à faible revenu (SFR-ApI) - Hommes')
# (721, 'Population immigrante (PI) - Hommes.2')
# (722, 'PI à faible revenu (SFR-ApI) - Hommes')
# (723, 'PI - Avant 2010 - Hommes')
# (724, 'Avant 2010 à faible revenu (SFR-ApI) - Hommes')
# (725, 'PI - 2011 à 2015 - Hommes')
# (726, '2011 à 2015 à faible revenu (SFR-ApI) - Hommes')
# (727, 'PI - 2016 à 2021 - Hommes')
# (728, '2016 à 2021 à faible revenu (SFR-ApI) - Hommes')
# (729, 'Population résidente non permanente (PRNP) - Hommes.1')
# (730, 'PRNP à faible revenu (SFR-ApI) - Hommes')
# (731, 'Population totale (PT) - Femmes')
# (732, 'PT à faible revenu (SFR-ApI) - Femmes')
# (733, 'Population non immigrante (PNI) - Femmes')
# (734, 'PNI à faible revenu (SFR-ApI) - Femmes')
# (735, 'Population immigrante (PI) - Femmes.2')
# (736, 'PI à faible revenu (SFR-ApI) - Femmes')
# (737, 'PI - Avant 2010 - Femmes')
# (738, 'Avant 2010 à faible revenu (SFR-ApI) - Femmes')
# (739, 'PI - 2011 à 2015 - Femmes')
# (740, '2011 à 2015 à faible revenu (SFR-ApI) - Femmes')
# (741, 'PI - 2016 à 2021 - Femmes')
# (742, '2016 à 2021 à faible revenu (SFR-ApI) - Femmes')
# (743, 'Population résidente non permanente (PRNP) - Femmes.1')
# (744, 'PRNP à faible revenu (SFR-ApI) - Femmes')
# (745, 'Population non-immigrante (PNI).1')
# (746, "PNI - Taux d'activité")
# (747, "PNI - Taux d'emploi")
# (748, 'PNI - Taux de chômage')
# (749, 'Population immigrante (PI).3')
# (750, "PI - Taux d'activité")
# (751, "PI - Taux d'emploi")
# (752, 'PI - Taux de chômage')
# (753, 'Population résidente non permanente (PRNP).2')
# (754, "PRNP - Taux d'activité")
# (755, "PRNP - Taux d'emploi")
# (756, 'PRNP - Taux de chômage')
# (757, 'Population non-immigrante (PNI) - Hommes.1')
# (758, "PNI - Taux d'activité - Hommes")
# (759, "PNI - Taux d'emploi - Hommes")
# (760, 'PNI - Taux de chômage - Hommes')
# (761, 'Population immigrante (PI) - Hommes.3')
# (762, "PI - Taux d'activité - Hommes")
# (763, "PI - Taux d'emploi - Hommes")
# (764, 'PI - Taux de chômage - Hommes')
# (765, 'Population résidente non permanente (PRNP) - Hommes.2')
# (766, "PRNP - Taux d'activité - Hommes")
# (767, "PRNP - Taux d'emploi - Hommes")
# (768, 'PRNP - Taux de chômage - Hommes')
# (769, 'Population non-immigrante (PNI) - Femmes.1')
# (770, "PNI - Taux d'activité - Femmes")
# (771, "PNI - Taux d'emploi - Femmes")
# (772, 'PNI - Taux de chômage - Femmes')
# (773, 'Population immigrante (PI) - Femmes.3')
# (774, "PI - Taux d'activité - Femmes")
# (775, "PI - Taux d'emploi - Femmes")
# (776, 'PI - Taux de chômage - Femmes')
# (777, 'Population résidente non permanente (PRNP) - Femmes.2')
# (778, "PRNP - Taux d'activité - Femmes")
# (779, "PRNP - Taux d'emploi - Femmes")
# (780, 'PRNP - Taux de chômage - Femmes')

# %%
print(df['Arrondissement'])
# Out:
# 0                  Agglomeration de Montreal
# 1                          Ville de Montreal
# 2                      Ahuntsic-Cartierville
# 3                                      Anjou
# 4           Cte-des-NeigesNotre-Dame-de-Grce
# 5                 L'le-BizardSainte-Genevive
# 6                                    LaSalle
# 7                                    Lachine
# 8               MercierHochelaga-Maisonneuve
# 9                               Montral-Nord
# 10                                 Outremont
# 11                       Pierrefonds-Roxboro
# 12    Rivire-des-PrairiesPointe-aux-Trembles
# 13                                RosemontLa
# 14                             Saint-Laurent
# 15                              Saint-Lonard
# 16                                    Verdun
# 17                               Ville-Marie
# 18        VilleraySaint-MichelParc-Extension
# 19                     Le_Plateau-Mont-Royal
# 20                              Le_Sud-Ouest
# Name: Arrondissement, dtype: object

# %% [markdown]
# Liste des variables pour le dataset de votes.

# %%
from preprocess import *

df = get_elections_data()
print(*enumerate(df.columns), sep='\n')

# %% [markdown]
# ## Cartes
#
# Proportion d'immigrants

# %%
from maps import *
from preprocess import *

df = get_demographics_data()
map_data = get_districts_mapdata()

fig = get_map(map_data, df["Immigrants"], zoom='Québec')
fig.show()

# %% [markdown]
# Proportion d'immigrants mais en ciblant Montréal seulement

# %%
from maps import *
from preprocess import *

df = get_demographics_data()
map_data = get_districts_mapdata()

# Only display the circos in montreal
mask = get_subset_mask(df['Circonscription'], circo_subsets['Montréal'])
color = df['Immigrants'].values
color[~mask] = None

fig = get_map(map_data, color, zoom='montreal')
fig.show()

# %% [markdown]
# Population d'immigrants par quartier de Montréal

# %%
from maps import *
from preprocess import *

df = get_immigration_data()
map_data = get_neighborhoods_mapdata()

fig = get_map(map_data, zoom='montreal')
fig.show()

# %% [markdown]
# Provenance des immigrants d'un certain quartier de Montréal [WIP]

# %%
from preprocess import *
from maps import *

arrondissement = 'Ville-Marie'
#arrondissement = 'Ahuntsic-Cartierville'

df = get_immigration_data()
mapdata = get_countries_mapdata()
color = get_countries_of_origin(arrondissement, df, mapdata)

fig = get_map(mapdata, color)
fig.update_layout(title=f'Where do {arrondissement}\'s immigrants come from?', width=1000, height=800)
fig.show()

# %% [markdown]
# Nombre de votes par circo, au total ou pour un parti spécifiquement.

# %%
from maps import *
from preprocess import *

party = 'P.L.Q./Q.L.P.'
#party = 'Q.S.'

df = get_elections_data()
df = vote_summary_by_circo(df)
#df = vote_summary_by_circo(df[df['abreviationPartiPolitique']==party])
map_data = get_districts_mapdata()

fig = get_map(map_data, df['nbVoteTotal'], zoom='quebec')
fig.show()

# %% [markdown]
# ## Autres

# %% [markdown]
# ### Correlation between immigration and vote for a given party (e.g. PLQ)

# %%
from preprocess import *
import plotly.express as px
import plotly.graph_objects as go

df_elections = get_elections_data()
df_elections = vote_summary_by_circo(df_elections[df_elections['abreviationPartiPolitique']=='P.L.Q./Q.L.P.'])
df_demographics = get_demographics_data()

assert df_elections['nomCirconscription'].equals(df_demographics['Circonscription'])

df = pd.DataFrame(
    data=np.array([
        df_demographics['Immigrants'].str.replace(',', '.').str.replace('%', '').astype(float),
        df_elections['tauxVote']]).T,
    columns=['Immigrants', 'tauxVote'])

fig = px.scatter(df, x='Immigrants', y='tauxVote')
fig.show()

# %% [markdown]
# ### Barplots pour quelques variables d'immigration

# %%
import plotly.express as px
import plotly.colors as colors
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

to_plot=[
    #'Population totale',
    'Immigrante',
    'Réfugiée',
    'Non permamente, Population résidente non permanente',
    'Continent Asie',
    'Continent Europe',
    'Continent Afrique',
    'Continent Amériques',
    'Continent Oceanie et autres lieux de naissance',
    'Parlant anglais à la maison',
    'Parlant français à la maison',
]

df = pd.read_csv('../assets/data/arrondissements.csv')
df = df.drop([0, 1]).reset_index(drop=True)

fig = make_subplots(rows=len(to_plot), cols=2, shared_xaxes=True, vertical_spacing=0.02, horizontal_spacing=0.1)
for i, col_name in enumerate(to_plot):
    fig.add_trace(go.Bar(
        x=df['Arrondissement'], 
        y=df[col_name], 
        name=col_name, 
        legendgroup=col_name,
        showlegend=True,
        marker_color=colors.qualitative.Plotly[i%len(colors.qualitative.Plotly)]), row=i+1, col=1)
    fig.add_trace(go.Bar(
        x=df['Arrondissement'], 
        y=df[col_name]/df['Population totale'], 
        legendgroup=col_name,
        showlegend=False,
        marker_color=colors.qualitative.Plotly[i%len(colors.qualitative.Plotly)]), row=i+1, col=2)
fig.update_layout(
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=1.02,
        xanchor='right',
        x=1),
    width=1000,
    height=800)
fig.show()

# %% [markdown]
# ### Pie chart des continents

# %%
import plotly.express as px
import plotly.colors as colors
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

to_plot=[
    #'Population totale',
    'Continent Asie',
    'Continent Europe',
    'Continent Afrique',
    'Continent Amériques',
    'Continent Oceanie et autres lieux de naissance',
    #'Parlant anglais à la maison',
    #'Parlant français à la maison',
]

df = pd.read_csv('../assets/data/arrondissements.csv')

fig = go.Figure(go.Pie(
    labels=to_plot,
    values=df.loc[0, to_plot], 
    name='Population totale'))

cols = [k for k in range(134, 193) if not df.columns[k].startswith('Continent')]

fig.show()
fig = go.Figure(go.Bar(
    x=df.columns[cols],
    y=df.iloc[0, cols],))
fig.update_layout(width=800)
fig.show()

# %% [markdown]
# ### Continents and countries sunburst chart

# %%
import plotly.express as px
import plotly.colors as colors
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

to_plot=[
    #'Population totale',
    'Continent Asie',
    'Continent Europe',
    'Continent Afrique',
    'Continent Amériques',
    'Continent Oceanie et autres lieux de naissance',
    #'Parlant anglais à la maison',
    #'Parlant français à la maison',
]

df = pd.read_csv('../assets/data/arrondissements.csv')

idx_continents = [k for k in range(134, 193) if df.columns[k].startswith('Continent')]
idx_countries = [k for k in range(134, 193) if not df.columns[k].startswith('Continent')]
parents_countries = ['Continent Amériques' for i in range(135, 146)]\
    + ['Continent Europe' for i in range(147, 163)]\
    + ['Continent Afrique' for i in range(164, 174)]\
    + ['Continent Asie' for i in range(175, 192)]

idx_americas = [k for k in range(135, 146)]
idx_europe = [k for k in range(147, 163)]
idx_africa = [k for k in range(164, 174)]
idx_asia = [k for k in range(175, 192)]
idx_oceania = [192]


print(df.columns[idx_continents])
print(len(idx_continents), len(idx_countries), len(parents_countries))
print(df.iloc[0, idx_continents])
sums = [sum(df.iloc[0, idx_americas]), sum(df.iloc[0, idx_europe]), sum(df.iloc[0, idx_africa]), sum(df.iloc[0, idx_asia]), sum(df.iloc[0, idx_oceania])]
print(sums)

labels = df.columns[idx_continents].to_list()\
        + df.columns[idx_americas].to_list()\
        + df.columns[idx_europe].to_list()\
        + df.columns[idx_africa].to_list()\
        + df.columns[idx_asia].to_list()\
        + df.columns[idx_oceania].to_list()

parents = ['']*len(idx_continents)\
        + [df.columns[idx_continents[0]]]*len(idx_americas)\
        + [df.columns[idx_continents[1]]]*len(idx_africa)\
        + [df.columns[idx_continents[2]]]*len(idx_europe)\
        + [df.columns[idx_continents[3]]]*len(idx_asia)\
        #+ [df.columns[idx_continents[4]]]*len(idx_oceania)

values = [0]*len(idx_continents) + df.iloc[0, idx_americas+idx_europe+idx_africa+idx_asia+idx_oceania].values.tolist()

fig = go.Figure(go.Sunburst(
    ids=labels,
    labels=labels,
    parents=parents,
    values=values,
))
fig.update_layout(width=800, height=800)
fig.show()
